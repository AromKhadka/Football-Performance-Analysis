# %%
import pandas as pd

# %%
Country = pd.read_csv('../data/raw/Country.csv')
League = pd.read_csv('../data/raw/League.csv')
Team = pd.read_csv('../data/raw/Team.csv')
Player = pd.read_csv('../data/raw/Player.csv')
Player_Attributes = pd.read_csv('../data/raw/Player_Attributes.csv')
Match = pd.read_csv('../data/raw/Match.csv')

# %%
for name, df in {
    "country": Country,
    "league": League,
    "team": Team,
    "player": Player,
    "player_attributes": Player_Attributes,
    "match": Match

}.items():
    print("___", name.upper(), "___")
    print(df.head())
    print(df.columns)
# Out:
# ___ COUNTRY ___
#       id     name
# 0      1  Belgium
# 1   1729  England
# 2   4769   France
# 3   7809  Germany
# 4  10257    Italy
# Index(['id', 'name'], dtype='str')
# ___ LEAGUE ___
#       id  country_id                    name
# 0      1           1  Belgium Jupiler League
# 1   1729        1729  England Premier League
# 2   4769        4769          France Ligue 1
# 3   7809        7809   Germany 1. Bundesliga
# 4  10257       10257           Italy Serie A
# Index(['id', 'country_id', 'name'], dtype='str')
# ___ TEAM ___
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB
# ...
